# %% [markdown]
# <h1 align=center> A comprehensive TensorFlow And PyTorch Resources </h1>
#
# - In this blog post, I am sharing resources to achieve proficiency in TensorFlow and PyTorch, the most commonly used frameworks in deep learning.
#
# ![tf_torch.png](attachment:tf_torch.png)
#
# # [1. TensorFlow](https://dev.mrdbourke.com/tensorflow-deep-learning/)
#
# - TensorFlow is an open-source machine learning framework developed by the Google Brain team. It is widely used for building and deploying machine learning and deep learning models
# - [TensorFlow_Resources Link](https://dev.mrdbourke.com/tensorflow-deep-learning/)
#
# ![tf.jpeg](attachment:tf.jpeg)
#
# ### Contents:
#
# 1. **Fundamentals:**
#     - [TF Fundamentals](https://dev.mrdbourke.com/tensorflow-deep-learning/00_tensorflow_fundamentals/)
#     - [Neural Network Regression with TF](https://dev.mrdbourke.com/tensorflow-deep-learning/01_neural_network_regression_in_tensorflow/)
#     - [Neural Network Classification with TF](https://dev.mrdbourke.com/tensorflow-deep-learning/02_neural_network_classification_in_tensorflow/)
# 2. **Computer Vision:**
#     - [CNN and Computer Vision with TF](https://dev.mrdbourke.com/tensorflow-deep-learning/03_convolutional_neural_networks_in_tensorflow/)
# 3. **Transfer Learning:**
#     - [Transfer Learning with TensorFlow Part 1: Feature Extraction](https://dev.mrdbourke.com/tensorflow-deep-learning/04_transfer_learning_in_tensorflow_part_1_feature_extraction/)
#     - [Transfer Learning with TensorFlow Part 2: Fine-tuning](https://dev.mrdbourke.com/tensorflow-deep-learning/05_transfer_learning_in_tensorflow_part_2_fine_tuning/)
#     - [Transfer Learning with TensorFlow Part 3: Scaling up](https://dev.mrdbourke.com/tensorflow-deep-learning/06_transfer_learning_in_tensorflow_part_3_scaling_up/)
#     - [Milestone Project 1](https://dev.mrdbourke.com/tensorflow-deep-learning/07_food_vision_milestone_project_1/)
# 4. **Natural Language Processing:**
#     - [NLP with TensorFlow](https://dev.mrdbourke.com/tensorflow-deep-learning/08_introduction_to_nlp_in_tensorflow/)
#     - [Milestone Project 2: SkimLit](https://dev.mrdbourke.com/tensorflow-deep-learning/09_SkimLit_nlp_milestone_project_2/)
# 5. **Time Series:**
#     - [Milestone Project 3: Time series forecasting in TensorFlow](https://dev.mrdbourke.com/tensorflow-deep-learning/10_time_series_forecasting_in_tensorflow/)
#
# # [2. PyTorch](https://www.learnpytorch.io/)
#
# - PyTorch is an open-source machine learning library developed by Facebook’s AI Research lab (FAIR). It is widely used for deep learning applications, including computer vision and natural language processing
# - [PyTorch_Resources Link](https://www.learnpytorch.io/)
#
# ![torch.jpg](attachment:torch.jpg)
#
# ### **Contents:**
#
# 1. [PyTorch Fundamentals](https://www.learnpytorch.io/00_pytorch_fundamentals/)
# 2. [PyTorch Workflow Fundamentals](https://www.learnpytorch.io/01_pytorch_workflow/)
# 3. [PyTorch Neural Network Classification](https://www.learnpytorch.io/02_pytorch_classification/)
# 4. [PyTorch Computer Vision](https://www.learnpytorch.io/03_pytorch_computer_vision/)
# 5. [PyTorch Custom Datasets](https://www.learnpytorch.io/04_pytorch_custom_datasets/#04-pytorch-custom-datasets)
# 6. [PyTorch Going Modular](https://www.learnpytorch.io/05_pytorch_going_modular/)
# 7. [PyTorch Transfer Learning](https://www.learnpytorch.io/06_pytorch_transfer_learning/)
# 8. [PyTorch Experiment Tracking](https://www.learnpytorch.io/07_pytorch_experiment_tracking/)
# 9. [PyTorch Paper Replicating](https://www.learnpytorch.io/08_pytorch_paper_replicating/)
# 10. [PyTorch Model Deployment](https://www.learnpytorch.io/09_pytorch_model_deployment/)
#
# `Note:` All credit goes to Daniel Bourke for his excellent courses on TensorFlow and PyTorch. I highly recommend completing his courses.
